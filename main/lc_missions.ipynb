# %% [markdown]
# From a pre-filtering target catalog, collect light curves from SPOC, QLP, TGLC, Eleanor-lite and NEMESIS for 30-minute cadence TESS prime mission photometry (from Sectors 1–26).

# %%
from fetching_lcs import fetch_tess_ffi_lcs

# %%
lcs = fetch_tess_ffi_lcs("TIC 302105449")
# Out:
# No data found for target "TIC 302105449".
